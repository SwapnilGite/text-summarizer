# %%
import os
import re
import pickle
import string
import unicodedata
from random import randint

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from wordcloud import STOPWORDS, WordCloud

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import Input, Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.layers import LSTM, Bidirectional, Dense, Embedding, TimeDistributed

# %%
import nltk

# %%
pip install wordcloud
# Out:
# Collecting wordcloudNote: you may need to restart the kernel to use updated packages.
#
#   Downloading wordcloud-1.8.2.2-cp39-cp39-win_amd64.whl (153 kB)
#      ------------------------------------ 153.1/153.1 kB 222.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in c:\python39\lib\site-packages (from wordcloud) (1.22.3)
# Requirement already satisfied: pillow in c:\python39\lib\site-packages (from wordcloud) (9.1.1)
# Requirement already satisfied: matplotlib in c:\python39\lib\site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\python39\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\python39\lib\site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\python39\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\python39\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\python39\lib\site-packages (from matplotlib->wordcloud) (3.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python39\lib\site-packages (from matplotlib->wordcloud) (4.37.1)
# Requirement already satisfied: six>=1.5 in c:\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.8.2.2

# %%
pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 990.4 kB/s eta 0:00:00
# Collecting regex>=2021.8.3
#   Downloading regex-2022.10.31-cp39-cp39-win_amd64.whl (267 kB)
#      -------------------------------------- 267.8/267.8 kB 1.0 MB/s eta 0:00:00
# Requirement already satisfied: joblib in c:\python39\lib\site-packages (from nltk) (1.1.0)
# Collecting click
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.6/96.6 kB 1.1 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\python39\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: colorama in c:\python39\lib\site-packages (from click->nltk) (0.4.4)
# Installing collected packages: regex, click, nltk
# Successfully installed click-8.1.3 nltk-3.8.1 regex-2022.10.31
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install -q contractions==0.0.48

# %%
from contractions import contractions_dict

for key, value in list(contractions_dict.items())[:20]:
    print(f'{key} == {value}')
# Out:
# I'm == I am
# I'm'a == I am about to
# I'm'o == I am going to
# I've == I have
# I'll == I will
# I'll've == I will have
# I'd == I would
# I'd've == I would have
# Whatcha == What are you
# amn't == am not
# ain't == are not
# aren't == are not
# 'cause == because
# can't == can not
# can't've == can not have
# could've == could have
# couldn't == could not
# couldn't've == could not have
# daren't == dare not
# daresn't == dare not

# %%
# # Using TPU

# # detect and init the TPU
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
# tf.config.experimental_connect_to_cluster(tpu)
# tf.tpu.experimental.initialize_tpu_system(tpu)

# # instantiate a distribution strategy
# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# %%
pwd
# Out:
# 'C:\\Users\\Dell\\OneDrive\\Desktop\\Data Science Project\\text_summarization'

# %% [markdown]
# # Getting The Data

# %%
filename = './Dataset.csv'

df1 = pd.read_csv(filename, encoding='iso-8859-1').reset_index(drop=True)

# %%
df1.drop('Unnamed: 1', inplace=True, axis=1)

# %%
df1.drop('Unnamed: 3', inplace=True, axis=1)

# %%
df1=df1.iloc[:296]

# %%
df1.sample(7)
# Out:
#                                             Input_Text  \
# 108  Meghalaya Chief Minister and National People's...
# 176  Forty MLAs, comprising 22 per cent of the Asse...
# 24   Alleging that the BJP-led government is not fo...
# 241  Congress General Secretary Priyanka Gandhi Vad...
# 82   Seizures totalling over Rs 147 crore have been...
# 234  Bahujan Samaj Party (BSP) chief Mayawati on Su...
# 229  Union Home Minister Amit Shah has targeted the...
#
#                                                 Source  \
# 108  https://www.ndtv.com/india-news/meghalaya-chie...
# 176  https://www.ndtv.com/india-news/in-gujarat-16-...
# 24   https://www.ndtv.com/india-news/pm-restless-ov...
# 241  https://www.ndtv.com/india-news/congress-leade...
# 82   https://www.ndtv.com/india-news/massive-rise-i...
# 234  https://www.ndtv.com/india-news/after-bjps-ram...
# 229  https://www.ndtv.com/india-news/new-parties-ca...
#
#                                                Summary
# 108  Conrad K Sangma filed his nomination papers fo...
# 176  40 MLAs have declared criminal cases against t...
# 24   Commenting on the Tripura elections, Congress ...
# 241  Priyanka Gandhi Vadra will take the final call...
# 82   Seizures worth over Rs 147 crore have been rec...
# 234  Mayawati attributed the defeat of the Samajwad...
# 229  Amit Shah has targeted the Aam Aadmi Party, sa...

# %%
print(f'Dataset size: {len(df1)}')
# Out:
# Dataset size: 296

# %% [markdown]
# # Data Preparation

# %%
def expand_contractions(text, contraction_map=contractions_dict):
    # Using regex for getting all contracted words
    contractions_keys = '|'.join(contraction_map.keys())
    contractions_pattern = re.compile(f'({contractions_keys})', flags=re.DOTALL)

    def expand_match(contraction):
        # Getting entire matched sub-string
        match = contraction.group(0)
        expanded_contraction = contraction_map.get(match)
        if not expand_contractions:
            print(match)
            return match
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)
    return expanded_text


expand_contractions("y'all can't expand contractions i'd think")
# Out:
# 'you all can not expand contractions id think'

# %%
df1.sample(3)
# Out:
#                                             Input_Text  \
# 269  "I had said during the campaign in Gujarat tha...
# 79   Voting for the 60-member Tripura Assembly is s...
# 109  The Election Commission (EC) on Friday suspend...
#
#                                                 Source  \
# 269  https://www.ndtv.com/india-news/gujarat-assemb...
# 79   https://www.ndtv.com/india-news/2023-tripura-a...
# 109  https://www.ndtv.com/india-news/election-body-...
#
#                                                Summary
# 269  PM Modi congratulated Bhupendra Patel for brea...
# 79   The Tripura Assembly election will be held tom...
# 109  The EC suspended a sub-divisional police offic...

# %%
# Converting to lowercase
df1.loc[:, "Input_Text"] = df1["Input_Text"].str.lower()
df1.loc[:, "Summary"] = df1["Summary"].str.lower()

df1.sample(3)
# Out:
#                                            Input_Text  \
# 86  bjp president j p nadda on tuesday asserted th...
# 38  a three-cornered high voltage election campaig...
# 8   argentina broke records for heat and cold with...
#
#                                                Source  \
# 86  https://www.ndtv.com/india-news/solution-to-na...
# 38  https://www.ndtv.com/india-news/tripura-all-se...
# 8   https://www.ndtv.com/world-news/heatwave-to-sn...
#
#                                               Summary
# 86  bjp president j p nadda said the solution to t...
# 38  the high voltage election campaign for tripura...
# 8   argentina experienced record-breaking heat fol...

# %%
print(type(df1.iloc[2]["Input_Text"]))
# Out:
# <class 'str'>

# %%
df1['Input_Text'].apply(lambda x: isinstance(x, str))
df1['Summary'].apply(lambda x: isinstance(x, str))
df1.sample(5)
# Out:
#                                             Input_Text  \
# 64   ãâ bjp's meteoric rise: the party had never...
# 255  the bharatiya janata party (bjp) has won the l...
# 184  mr sukhu was born into a humble rural family. ...
# 286  the aam aadmi party (aap) and the asaduddin ow...
# 190  around 25 cabinet ministers will also take an ...
#
#                                                 Source  \
# 64   https://www.ndtv.com/india-news/tripura-electi...
# 255  https://www.ndtv.com/india-news/bjp-wins-gujar...
# 184  https://www.ndtv.com/india-news/5-facts-on-suk...
# 286  https://www.ndtv.com/india-news/gujarat-aap-ai...
# 190  https://www.ndtv.com/india-news/gujarat-electi...
#
#                                                Summary
# 64   the bjp's success in tripura is attributed to ...
# 255  the bharatiya janata party (bjp) has won the l...
# 184  mr sukhu was born into a humble rural family a...
# 286  the aam aadmi party (aap) and the asaduddin ow...
# 190  the bjp won a landslide victory in gujarat, wi...

# %%
df1 = df1.dropna()

# %%
# Removing rows with empty cell
print(f'Dataset size: {len(df1)}')
# Out:
# Dataset size: 290

# %%
df1.Input_Text = df1.Input_Text.apply(expand_contractions)
df1.Summary = df1.Summary.apply(expand_contractions)
df1.sample(5)
# Out:
#                                             Input_Text  \
# 47   the 2023 meghalaya assthembly election will wi...
# 290  the aam aadmi party (aap) and the asaduddin ow...
# 125  the bjp will contest on all 60 seats of the me...
# 269  "i had said during the campaign in gujarat tha...
# 19   the congress in meghalaya alleged that the rul...
#
#                                                 Source  \
# 47   https://www.ndtv.com/india-news/2023-meghalaya...
# 290  https://www.ndtv.com/india-news/gujarat-aap-ai...
# 125  https://www.ndtv.com/india-news/bjp-to-contest...
# 269  https://www.ndtv.com/india-news/gujarat-assemb...
# 19   https://www.ndtv.com/india-news/meghalaya-poll...
#
#                                                Summary
# 47   multi-cornered contests in meghalaya and tripu...
# 290  the aam aadmi party (aap) and the asaduddin ow...
# 125  the bjp will contest the meghalaya and nagalan...
# 269  pm modi congratulated bhupendra patel for brea...
# 19   congress alleges npp failed to protect women a...

# %%
# Remove puncuation from word
def rm_punc_from_word(word):
    clean_alphabet_list = [
        alphabet for alphabet in word if alphabet not in string.punctuation
    ]
    return ''.join(clean_alphabet_list)

print(rm_punc_from_word('#cool!'))


# Remove puncuation from text
def rm_punc_from_text(text):
    clean_word_list = [rm_punc_from_word(word) for word in text]
    return ''.join(clean_word_list)

print(rm_punc_from_text("Frankly, my dear, I don't give a damn"))
# Out:
# cool
# Frankly my dear I dont give a damn

# %%
# Remove numbers from text
def rm_number_from_text(text):
    text = re.sub('[0-9]+', '', text)
    return ' '.join(text.split())  # to rm `extra` white space

print(rm_number_from_text('You are 100times more sexier than me'))
print(rm_number_from_text('If you taught yes then you are 10 times more delusional than me'))
# Out:
# You are times more sexier than me
# If you taught yes then you are times more delusional than me

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Remove stopwords from text
def rm_stopwords_from_text(text):
    _stopwords = stopwords.words('english')
    text = text.split()
    word_list = [word for word in text if word not in _stopwords]
    return ' '.join(word_list)

rm_stopwords_from_text("Love means never having to say you're sorry")
# Out:
# 'Love means never say sorry'

# %%
# Cleaning text
def clean_text(text):
    text = text.lower()
    text = rm_punc_from_text(text)
    text = rm_number_from_text(text)
    text = rm_stopwords_from_text(text)

    # there are hyphen(–) in many titles, so replacing it with empty str
    # this hyphen(–) is different from normal hyphen(-)
    text = re.sub('–', '', text)
    text = ' '.join(text.split())  # removing `extra` white spaces

    # Removing unnecessary characters from text
    text = re.sub("(\\t)", ' ', str(text)).lower()
    text = re.sub("(\\r)", ' ', str(text)).lower()
    text = re.sub("(\\n)", ' ', str(text)).lower()

    # remove accented chars ('Sómě Áccěntěd těxt' => 'Some Accented text')
    text = unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode(
        'utf-8', 'ignore'
    )

    text = re.sub("(__+)", ' ', str(text)).lower()
    text = re.sub("(--+)", ' ', str(text)).lower()
    text = re.sub("(~~+)", ' ', str(text)).lower()
    text = re.sub("(\+\++)", ' ', str(text)).lower()
    text = re.sub("(\.\.+)", ' ', str(text)).lower()

    text = re.sub(r"[<>()|&©ø\[\]\'\",;?~*!]", ' ', str(text)).lower()

    text = re.sub("(mailto:)", ' ', str(text)).lower()
    text = re.sub(r"(\\x9\d)", ' ', str(text)).lower()
    text = re.sub("([iI][nN][cC]\d+)", 'INC_NUM', str(text)).lower()
    text = re.sub("([cC][mM]\d+)|([cC][hH][gG]\d+)", 'CM_NUM',
                  str(text)).lower()

    text = re.sub("(\.\s+)", ' ', str(text)).lower()
    text = re.sub("(\-\s+)", ' ', str(text)).lower()
    text = re.sub("(\:\s+)", ' ', str(text)).lower()
    text = re.sub("(\s+.\s+)", ' ', str(text)).lower()

    try:
        url = re.search(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', str(text))
        repl_url = url.group(3)
        text = re.sub(r'((https*:\/*)([^\/\s]+))(.[^\s]+)', repl_url, str(text))
    except Exception as e:
        pass

    text = re.sub("(\s+)", ' ', str(text)).lower()
    text = re.sub("(\s+.\s+)", ' ', str(text)).lower()

    return text

clean_text("Mrs. Robinson, you're trying to seduce me, aren't you?")
# Out:
# 'mrs robinson youre trying seduce arent'

# %%
df1.loc[:, "Input_Text"] = df1["Input_Text"].apply(clean_text)
df1.loc[:, "Summary"] = df1["Summary"].apply(clean_text)


df1.sample(5)
# Out:
#                                             Input_Text  \
# 202  jds leadership saturday named former chief min...
# 210  tripura chief minister manik saha opted rather...
# 197  urging party workers ensure bjp forms governme...
# 287  samajwadi party candidate dimple yadav prestig...
# 267  congress victory northern state seen silver li...
#
#                                                 Source  \
# 202  https://www.ndtv.com/karnataka-news/karnataka-...
# 210  https://www.ndtv.com/india-news/tripura-chief-...
# 197  https://www.ndtv.com/india-news/bjp-to-contest...
# 287  https://www.ndtv.com/india-news/watch-celebrat...
# 267  https://www.ndtv.com/india-news/congress-sachi...
#
#                                                Summary
# 202  jds named nikhil kuswamy candidate assthembly ...
# 210  tripura chief minister manik saha gone doortod...
# 197  amit shah asserted bjp go alone karnataka asst...
# 287  dimple yadav lok sabha seat mainpuri two lakh ...
# 267  congress victory himachal seen silver lining b...

# %%
df1.to_csv('cleaned_data.csv')

# %%
# To customize colours of wordcloud texts
def wc_blue_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return "hsl(214, 67%%, %d%%)" % randint(60, 100)


# stopwords for wordcloud
def get_wc_stopwords():
    wc_stopwords = set(STOPWORDS)

    # Adding words to stopwords
    # these words showed up while plotting wordcloud for text
    wc_stopwords.add('s')
    wc_stopwords.add('one')
    wc_stopwords.add('using')
    wc_stopwords.add('example')
    wc_stopwords.add('work')
    wc_stopwords.add('use')
    wc_stopwords.add('make')

    return wc_stopwords


# plot wordcloud
def plot_wordcloud(text, color_func):
    wc_stopwords = get_wc_stopwords()
    wc = WordCloud(stopwords=wc_stopwords, width=1200, height=600, random_state=0).generate(text)

    f, axs = plt.subplots(figsize=(20, 10))
    with sns.axes_style("ticks"):
        sns.despine(offset=10, trim=True)
        plt.imshow(wc.recolor(color_func=color_func, random_state=0), interpolation="bilinear")
        plt.xlabel('WordCloud')

# %%
plot_wordcloud(' '.join(df1.Input_Text.values.tolist()), wc_blue_color_func)

# %%
plot_wordcloud(' '.join(df1.Summary.values.tolist()), wc_blue_color_func)

# %%
df1.Input_Text = df1.Input_Text.apply(lambda x: f'_START_ {x} _END_')

# %%
df1.Summary = df1.Summary.apply(lambda x: f'_START_ {x} _END_')

# %%
df1.iloc[2]["Input_Text"]
# Out:
# '_START_ union housing urban affairs ministry ded take properties delhi waqf board including mosques dargahs graveyards evoking sharp reaction board chairman aap mla amanatullah khanmr khan asserted allow central government take waqf propertiesthe deputy land development officer letter board uary informed sion absolve matters pertaining waqf propertiesthe land development office ldo central ministry said twomthember committee headed justice retired sp garg issue denotified waqf properties report submitted representation objection received delhi waqf board _END_'

# %%
text_count = [len(sentence.split()) for sentence in df.text]
headlines_count = [len(sentence.split()) for sentence in df.headlines]

pd.DataFrame({'text': text_count, 'headlines': headlines_count}).hist(bins=100, figsize=(16, 4), range=[0, 50])
plt.show()

# %%
SummaryCount = [len(sentence.split()) for sentence in df1.Summary]
Input_TextCount = [len(sentence.split()) for sentence in df1.Input_Text]

pd.DataFrame({'SummaryCount': SummaryCount, 'Input_TextCount': Input_TextCount}).hist(bins=100, figsize=(16, 4), range=[0, 50])
plt.show()

# %%
# To check how many rows in a column has length (of the text) <= limit
def get_word_percent(column, limit):
    count = 0
    for sentence in column:
        if len(sentence.split()) <= limit:
            count += 1

    return round(count / len(column), 2)


# Check how many % of headlines have 0-100 words
print(get_word_percent(df1.Input_Text, 100))

# Check how many % of summary have 0-30 words
print(get_word_percent(df1.Summary, 35))
# Out:
# 0.98
# 0.83

# %%
max_input_text_len = 100
max_summary_len = 35

# %%
# select the summary and text between their defined max lens respectively
def trim_text_and_summary(df, max_input_text_len, max_summary_len):
    cleaned_text = np.array(df['Input_Text'])
    cleaned_summary = np.array(df['Summary'])

    short_text = []
    short_summary = []

    for i in range(len(cleaned_text)):
        if len(cleaned_text[i].split()) <= max_input_text_len and len(
            cleaned_summary[i].split()
        ) <= max_summary_len:
            short_text.append(cleaned_text[i])
            short_summary.append(cleaned_summary[i])

    df = pd.DataFrame({'text': short_text, 'summary': short_summary})
    return df


df2 = trim_text_and_summary(df1, max_input_text_len, max_summary_len)
print(f'Original Dataset size: {len(df1)}')
print(f'After Dataset size: {len(df2)}')
df2.sample(5)
# Out:
# Original Dataset size: 290
# After Dataset size: 237
#                                                   text  \
# 202  _START_ urging party workers ensure bjp forms ...
# 81   _START_ choosing bjp guarantee development und...
# 226  _START_ sign growing trouble congress victory ...
# 201  _START_ himachal pradesh deputy chief minister...
# 90   _START_ bjp contest seats meghalaya assthembly...
#
#                                                summary
# 202  amit shah asserted bjp go alone karnataka asst...
# 81   choosing bjp guarantee development prime minis...
# 226  party workers himachal pradesh blocked convoy ...
# 201  mukesh agnihotri sukhvinder sukhu taken oath n...
# 90   bjp contest meghalaya nagaland elections campa...
